# %% [markdown]
# #REPORT

# %% [markdown]
# #BANK CHURN

# %% [markdown]
# #OBJECTIVES
#
# Selecting the Best Models:
#
#
# •	Clustering or Segment the Data- Employ clustering algorithms to partition the dataset into distinct segments or clusters based on relevant features such as credit score, age, tenure, balance, products number, and estimated salary. The primary goal is to identify natural groupings within the customer data.
#
# •	Determine the Number of Segments/Clusters- Explore various methods, such as the Elbow Method or Silhouette Analysis, to determine the optimal number of segments or clusters. The objective is to find a balance between creating meaningful segments and avoiding unnecessary fragmentation.
#
# •	Characterize Segments/Clusters - Analyze and characterize each identified segment or cluster based on the features that define them. Understand the unique characteristics, behaviors, and profiles of customers within each cluster. This involves extracting insights on credit score distribution, age patterns, tenure, balance trends, product usage, and estimated salary for each segment.

# %% [markdown]
# #SOURCE OF DATA
#
# Kaggle- Bank Churn
#
# https://www.kaggle.com/datasets/rangalamahesh/bank-churn?resource=download

# %% [markdown]
# #DATA SIZE
#
# 7 MB

# %% [markdown]
# # ABOUT DATA SET
#
# NUMBER OF COLUMNS - 13
#
# NUMBER OF ROWS - 110023
#
# •	id: Unique identifier for each record.
#
# •	CustomerId: Unique identifier for each customer.
#
# •	Surname: Last name of the customer.
#
# •	CreditScore: Numerical representation of the customer's creditworthiness.
#
# •	Geography: Country of residence for the customer.
#
# •	Gender: Gender of the customer (Male/Female).
#
# •	Age: Age of the customer.
#
# •	Tenure: Number of years the customer has been with the bank.
#
# •	Balance: Current balance in the customer's account.
#
# •	NumOfProducts: Number of products held by the customer.
#
# •	HasCrCard: Binary indicator of whether the customer has a credit card (1 for Yes, 0 for No).
#
# •	IsActiveMember: Binary indicator of whether the customer is an active member (1 for Yes, 0 for No).
#
# •	EstimatedSalary: Estimated annual salary of the customer
#
#
# •	This dataset give information about the caracteristics of customer and if they have churned or not. The idea is study the carcateristics search what is the cause of customer churn and generate a model that will be capable of predict if one user will churn the bank.
#
# #Categorising the data
#
# *  Categorical data - Geography, Gender, age, tenure, number of products, hascrcard, is activemember, surname
# *  Non categorical - Customer ID, ID, creditscore, Balance, Estimated salary
#
#
#
#
#
# *   Nominal- Id, CustomerId, Surname, Geography, Gender, HasCrCard, IsActiveMember
#
#
# *   Ordinal- CreditScore, Age, Tenure, NumOfProducts

# %% [markdown]
# #INFORMATION REGARDING MISSING DATA
#
# In terms of individual fields, there are no instances of missing values across any columns in the dataset. Examining the records, out of the total 110023 entries, there is no occurrence of missing data on a record-by-record basis. All records contain complete and non-null information.

# %% [markdown]
# #TREATMENT OF MISSING DATA
#
# As seen, there are no missing or duplicate data, there are 3 string and 10 number data, and the data have diferents number values, fot that it's necesary transform and normalizate.

# %% [markdown]
# Removal of Variables or Features with More Than 50% Missing Data: None

# %% [markdown]
# Missing Data Statistics(Categorical Variables or Features) : None

# %% [markdown]
# #RESULTS

# %% [markdown]
# Number of Segements - 4
#
# Appropriate Model is : K-Means
#
# Cluster Identified are : The clusters are heterogeneous among themselves. Each cluster represents a unique group of seismic events with varying characteristics, indicating heterogeneity across the clusters.

# %% [markdown]
# #MANAGERIAL IMPLICATIONS
#
# Appropriate Model - K Means
#
# Appropriate segements - 4
#
# Cluster (0) - "High Cohesion, High Separation"
#
# Silhouette Score (SS):
#
# The SS score of 0.5492 indicates a moderate level of separation and cohesion among the clusters. A score closer to 1 suggests dense and well-separated clusters, while a score closer to -1 indicates overlapping clusters.
#
# Davies-Bouldin Score (DB):
#
# The DB score of 0.7635 suggests that the clusters are relatively well-separated, but there may be some overlap or ambiguity in cluster boundaries. Lower DB scores indicate better clustering, with values closer to 0 representing clear and distinct clusters.
#
# cluster (1) - "Moderate Cohesion, Moderate Separation"
#
# Silhouette Score (SS):
#
# The SS score of 0.5362 indicates a moderate level of separation and cohesion among the clusters. A score closer to 1 suggests dense and well-separated clusters, while a score closer to -1 indicates overlapping clusters. While the SS score is not exceptionally high, it still suggests a reasonable clustering arrangement with some degree of distinctiveness among clusters.
#
# Davies-Bouldin Score (DB):
#
# The DB score of 0.5697 suggests that the clusters are relatively well-separated, but there may be some overlap or ambiguity in cluster boundaries. Lower DB scores indicate better clustering, with values closer to 0 representing clear and distinct clusters. The obtained DB score indicates a moderate level of clustering quality, with room for potential improvement in cluster separation.
#
# Cluster (2) - "High Cohesion, Moderate Separation"
#
# Silhouette Score (SS):
#
# The SS score of 0.5512 indicates a moderate level of separation and cohesion among the clusters. A score closer to 1 suggests dense and well-separated clusters, while a score closer to -1 indicates overlapping clusters. While the SS score is not exceptionally high, it still suggests a reasonable clustering arrangement with some degree of distinctiveness among clusters.
#
# Davies-Bouldin Score (DB):
#
# The DB score of 0.6384 suggests that the clusters are relatively well-separated, but there may be some overlap or ambiguity in cluster boundaries. Lower DB scores indicate better clustering, with values closer to 0 representing clear and distinct clusters. The obtained DB score indicates a moderate level of clustering quality, with room for potential improvement in cluster separation.
#
# Cluster (3) - "Low Cohesion, Moderate Separation"
#
# Silhouette Score (SS):
#
# The SS score of 0.5182 suggests a moderate level of separation and cohesion among the clusters. A score closer to 1 indicates dense, well-separated clusters, while a score closer to -1 suggests overlapping clusters. While the SS score is not exceptionally high, it still indicates a reasonable clustering arrangement with some degree of distinctiveness among clusters.
#
# Davies-Bouldin Score (DB):
#
# The DB score of 0.6394 indicates that the clusters are relatively well-separated, but there may be some overlap or ambiguity in cluster boundaries. Lower DB scores represent better clustering, with values closer to 0 indicating clear and distinct clusters. The obtained DB score suggests a moderate level of clustering quality, with potential room for improvement in cluster separation.

# %% [markdown]
# #Data Analysis
#
# Chi Square
#
# >>>>*Null Hypothesis (H0):* There is no significant difference in the mean latitude among clusters 0, 1, and 2.
#
# >>>>*Alternate Hypothesis (H1):* There is a significant difference in the mean latitude among at least two of the clusters (0, 1, and 2).
#
# ![image.png](data:image/png;base64,...)
#
# Despite having a relatively high Chi-square value, the p-value suggests that age is not significantly associated with the target variable. This indicates that customers' ages may not have a substantial impact on the outcome being studied.
#
# • tenure exhibits a significant association with the target variable, as evidenced by the low p-value. This implies that the length of time a customer has been with the bank could be a critical factor influencing the outcome.
#
# • The analysis suggests that the number of products held by customers does not have a significant association with the target variable. Thus, the quantity of products utilized by customers may not strongly influence the outcome.
#
# • holding a credit card does not appear to be significantly associated with the target variable. This implies that possessing a credit card may not be a determining factor in the outcome under consideration.
#
# • Active membership status shows a significant association with the target variable, as indicated by the low p-value. This suggests that customers' engagement with bank services as active members may impact the outcome being analyzed.

# %% [markdown]
# Annova
#
# >>>>*Null Hypothesis (H0):* There is no significant difference in the mean magnitude among clusters 0, 1, and 2.
#
# >>>>*Alternate Hypothesis (H1):* There is a significant difference in the mean magnitude among at least two of the clusters (0, 1, and 2).
#
# Balance - statistic=489499.2594413773, pvalue=0.0
#
# Since the p-value is less than the significance level (usually 0.05), we reject the null hypothesis, suggesting that there are statistically significant differences in the mean 'Balance' across at least one pair of clusters.
# The high F-statistic further supports the rejection of the null hypothesis, indicating substantial variation in 'Balance' among the clusters.
# Therefore, we can conclude that there are significant differences in the mean 'Balance' across the clusters, implying that the 'Balance' variable contributes significantly to distinguishing between the clusters.
#
#
# Estimated salary - statistic=97042.28085304164, pvalue=0.0
#
# With a p-value significantly lower than the typical significance level of 0.05, we reject the null hypothesis, indicating that there are statistically significant differences in the mean 'EstimatedSalary' across at least one pair of clusters.
# The high F-statistic further supports the rejection of the null hypothesis, suggesting substantial variation in 'EstimatedSalary' among the clusters.
# Consequently, we can conclude that the 'EstimatedSalary' variable significantly influences the clustering of data, underscoring its importance in delineating customer segments based on their salary estimations.
#
#
# Credit scpre - statistic=2.049253433681099, pvalue=0.10464511169584538
#
# With a p-value greater than the conventional significance level of 0.05, we fail to reject the null hypothesis.
# The obtained p-value suggests that there is no statistically significant difference in the mean 'CreditScore_y' among the clusters.
# Therefore, we infer that the 'CreditScore_y' variable may not significantly contribute to the clustering of data, as there is insufficient evidence to support its influence on cluster formation.

# %% [markdown]
# #CONCLUSION
#
# In conclusion, the analysis of ABC Multistate Bank's customer data has provided valuable insights into predicting and mitigating customer churn. The dataset, comprising diverse variables such as credit score, country, gender, age, and financial details, was meticulously prepared, ensuring data integrity for subsequent machine learning algorithms. Through clustering analysis, including the application of the K-Means algorithm, distinct patterns within the customer base were identified. The Elbow Method suggested an optimal number of clusters (k=4), forming segments that were visually interpreted in a 3D space. The clusters represented unique customer segments based on credit score and estimated salary, offering a foundation for targeted strategies. Managerial implications included tailored marketing, product development, and customer service strategies for each cluster, catering to their specific financial profiles. Recommendations for continuous monitoring, collaboration with stakeholders, and further exploration were highlighted, emphasizing the dynamic nature of customer behaviors and the need for adaptive strategies. Overall, the analysis equips ABC Multistate Bank with actionable insights to proactively address customer churn, enhance satisfaction, and navigate the evolving financial landscape effectively.

# %%
# Required Libraries
import pandas as pd, numpy as np # For Data Manipulation
from sklearn.preprocessing import LabelEncoder, OrdinalEncoder # For Encoding Categorical Data [Nominal | Ordinal]
from sklearn.preprocessing import OneHotEncoder # For Creating Dummy Variables of Categorical Data [Nominal]
from sklearn.impute import SimpleImputer, KNNImputer # For Imputation of Missing Data
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler # For Rescaling Data
from sklearn.model_selection import train_test_split # For Splitting Data into Training & Testing Sets
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as sps # For Probability & Inferential Statistics
import time
import psutil
from sklearn.cluster import Birch

# %%
from google.colab import files
import pandas as pd
import io

# Upload the file
uploaded = files.upload()

# Get the file name
file_name = next(iter(uploaded))

# Read the uploaded file into a DataFrame
df = pd.read_csv(io.BytesIO(uploaded[file_name]))

# Display the DataFrame
print(df)
# Out:
#      <input type="file" id="files-b9386405-5486-4b0a-a2f5-be12cc67bea6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b9386405-5486-4b0a-a2f5-be12cc67bea6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df_cat = df[['Geography', 'Gender','Age','Tenure','NumOfProducts','HasCrCard','IsActiveMember','Surname']] # Categorical Data [Nominal | Ordinal]
df_noncat = df[['CustomerId', 'id','CreditScore','Balance','EstimatedSalary']] # Non-Categorical Data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110023 entries, 0 to 110022
# Data columns (total 13 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   id               110023 non-null  int64
#  1   CustomerId       110023 non-null  int64
#  2   Surname          110023 non-null  object
#  3   CreditScore      110023 non-null  int64
#  4   Geography        110023 non-null  object
#  5   Gender           110023 non-null  object
#  6   Age              110023 non-null  float64
#  7   Tenure           110023 non-null  int64
#  8   Balance          110023 non-null  float64
#  9   NumOfProducts    110023 non-null  int64
#  10  HasCrCard        110023 non-null  float64
#  11  IsActiveMember   110023 non-null  float64
#  12  EstimatedSalary  110023 non-null  float64
# dtypes: float64(5), int64(5), object(3)
# memory usage: 10.9+ MB

# %%
# Determine the number of rows and columns for the subplot grid
num_rows = 2  # Adjust as needed based on the number of categorical variables
num_cols = (len(df_cat.columns) + 1) // 2  # Divide the columns into two halves

# Create a subplot grid
fig, axes = plt.subplots(nrows=num_rows, ncols=num_cols, figsize=(14,10))

# Iterate over each categorical variable
for i, column in enumerate(df_cat.columns):
    # Calculate value counts for the current column
    value_counts = df_cat[column].value_counts()

    # Calculate the row and column index for the current subplot
    row_index = i // num_cols
    col_index = i % num_cols

    # Create a pie chart on the corresponding subplot
    ax = axes[row_index, col_index]
    ax.pie(value_counts, labels=value_counts.index, autopct='%1.1f%%', startangle=140)
    ax.set_title(f"Pie Chart of {column}")
    ax.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle

# Adjust layout and spacing
plt.tight_layout()
plt.show()

# %%
variable_missing_data = df.isna().sum(); variable_missing_data # Variable-wise Missing Data Information
# Out:
# id                 0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# dtype: int64

# %%
record_missing_data = df.isna().sum(axis=1).sort_values(ascending=False).head(5); record_missing_data # Record-wise Missing Data Information (Top 5)
# Out:
# 0        0
# 73358    0
# 73356    0
# 73355    0
# 73354    0
# dtype: int64

# %%
# Using Scikit Learn : Ordinal Encoder (Superior)
oe = OrdinalEncoder()
df_cat_mdt = df_cat.copy()
oe_fit = oe.fit_transform(df_cat_mdt)
df_cat_code_oe = pd.DataFrame(oe_fit, columns=['Geography', 'Gender','Age','Tenure','NumOfProducts','HasCrCard','IsActiveMember','Surname']); df_cat_code_oe
#df_cat_mdt_code_oe = df_cat_mdt.join(df_cat_code_oe); df_cat_mdt_code_oe # (Missing Data Treated) Numeric Coded Categorical Dataset using Scikit Learn Ordinal Encoder
df_cat_mdt_code_oe = pd.merge(df_cat_mdt, df_cat_code_oe, left_index=True, right_index=True); df_cat_mdt_code_oe
# Out:
#        Geography_x Gender_x  Age_x  Tenure_x  NumOfProducts_x  HasCrCard_x  \
# 0           France   Female   23.0         2                2          0.0
# 1           France   Female   46.0         2                1          1.0
# 2           France   Female   34.0         7                2          1.0
# 3           France     Male   36.0         8                1          1.0
# 4          Germany     Male   38.0        10                1          1.0
# ...            ...      ...    ...       ...              ...          ...
# 110018       Spain     Male   29.0         7                1          1.0
# 110019      France   Female   36.0         4                1          1.0
# 110020      France     Male   31.0         2                2          1.0
# 110021      France   Female   32.0         3                1          1.0
# 110022      France   Female   37.0         7                1          1.0
#
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming df_noncat is your DataFrame containing the specified columns
columns = ['CustomerId', 'id', 'CreditScore', 'Balance', 'EstimatedSalary']

# Creating box plots for each column
plt.figure(figsize=(12, 8))
sns.set(style="whitegrid")
sns.boxplot(data=df_noncat[columns], orient="h", palette="Set2")
plt.title("Box Plot of Various Numeric Features")
plt.xlabel("Value")
plt.show()

# %% [markdown]
# •	Customer ID: This feature likely serves as a unique identifier for each customer and isn't directly comparable across individuals. Therefore, it doesn't have a meaningful distribution to analyze in the context of this boxplot.
#
# •	Credit Score: The credit score distribution exhibits a positive skew, with a median score around 600 and a longer tail extending towards higher scores. This indicates that a larger portion of customers have scores concentrated around the median, with fewer customers having exceptionally high or low credit scores.
#
# •	Estimated Salary: The estimated salary distribution also shows a positive skew, with a median salary of approximately $40,000 and a longer tail towards higher salaries. This suggests that a larger portion of customers have salaries clustered around the median, with fewer customers having very high or very low estimated salaries.
#
# •Balance: The balance distribution appears relatively symmetrical, with a median around $ 0 and whiskers extending roughly equal distances on either side. This suggests that the majority of customers have balances centered near $0, with some having positive or negative balances.

# %%
for i in ['CustomerId', 'id','CreditScore','Balance','EstimatedSalary']:
    # Calculate the standard deviation of each column
    std1 = round(np.std(df_noncat[i]), 2)
    print(f"Standard deviation of'{i}': {std1}")
# Out:
# Standard deviation of'CustomerId': 71684.67
# Standard deviation of'id': 31760.9
# Standard deviation of'CreditScore': 80.32
# Standard deviation of'Balance': 62788.23
# Standard deviation of'EstimatedSalary': 50276.82

# %%
sns.boxplot(df, x='Age');

# %% [markdown]
# As can look, the age have incidence in the customer exited, it is more likely that old people exited and the likely increased between 44 to 64 age. Also, we can look that the age and gender there aren't relationship, but female have more likely of exited without age import.

# %%
corr = df[[ 'CreditScore',  'Age',
       'Tenure', 'Balance',
       'EstimatedSalary']].corr()
# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(10, 8))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=1, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5}, annot=True)
# Out:
# <Axes: >

# %%
# 3.2.2. Normalization : Robust Scaling
df_noncat_mdt = df_noncat.copy()
rs = RobustScaler(quantile_range=(10.0, 90.0)) # quantile_range=(25.0, 75.0) - Default Range
rs_fit = rs.fit_transform(df_noncat_mdt[['CreditScore']])
df_noncat_robust_norm = pd.DataFrame(rs_fit, columns=['CreditScore_y']); df_noncat_robust_norm
#df_noncat_robust_norm = pd.DataFrame(rs_fit, columns=df_noncat_mdt.columns+'_y'); df_noncat_robust_norm
#df_noncat_mdt_rn = df_noncat_mdt.join(df_noncat_robust_norm); df_noncat_mdt_rn # (Missing Data Treated) Normalized Non-#Categorical Dataset using Scikit Learn Robust Scaler
df_noncat_mdt_rn = pd.merge(df_noncat_mdt[['CustomerId', 'id','Balance','EstimatedSalary']], df_noncat_robust_norm, left_index=True, right_index=True); df_noncat_mdt_rn
# Out:
#         CustomerId      id    Balance  EstimatedSalary  CreditScore_y
# 0         15773898  165034       0.00        160976.75         -0.370
# 1         15782418  165035       0.00         72549.27          0.115
# 2         15807120  165036       0.00        138882.09         -0.020
# 3         15808905  165037       0.00        113931.57          0.105
# 4         15607314  165038  121263.62        139431.00          0.460
# ...            ...     ...        ...              ...            ...
# 110018    15662091  275052  116099.82        148087.62         -0.450
# 110019    15774133  275053  178032.53         42181.68         -0.425
# 110020    15728456  275054       0.00         16287.38          0.260
# 110021    15687541  275055       0.00        158816.58          0.245
# 110022    15663942  275056   87848.39         24210.56         -0.195
#
# [110023 rows x 5 columns]

# %%
# Pre-Processed Categorical Data Subset
df_cat_ppd = df_cat_mdt_code_oe.copy(); df_cat_ppd # Preferred Data Subset
# Out:
#        Geography_x Gender_x  Age_x  Tenure_x  NumOfProducts_x  HasCrCard_x  \
# 0           France   Female   23.0         2                2          0.0
# 1           France   Female   46.0         2                1          1.0
# 2           France   Female   34.0         7                2          1.0
# 3           France     Male   36.0         8                1          1.0
# 4          Germany     Male   38.0        10                1          1.0
# ...            ...      ...    ...       ...              ...          ...
# 110018       Spain     Male   29.0         7                1          1.0
# 110019      France   Female   36.0         4                1          1.0
# 110020      France     Male   31.0         2                2          1.0
# 110021      France   Female   32.0         3                1          1.0
# 110022      France   Female   37.0         7                1          1.0
#
# ...

# %%
# Pre-Processed Non-Categorical Data Subset
df_noncat_ppd = df_noncat_mdt_rn.copy(); df_noncat_ppd # Preferred Data Subset
# Out:
#         CustomerId      id    Balance  EstimatedSalary  CreditScore_y
# 0         15773898  165034       0.00        160976.75         -0.370
# 1         15782418  165035       0.00         72549.27          0.115
# 2         15807120  165036       0.00        138882.09         -0.020
# 3         15808905  165037       0.00        113931.57          0.105
# 4         15607314  165038  121263.62        139431.00          0.460
# ...            ...     ...        ...              ...            ...
# 110018    15662091  275052  116099.82        148087.62         -0.450
# 110019    15774133  275053  178032.53         42181.68         -0.425
# 110020    15728456  275054       0.00         16287.38          0.260
# 110021    15687541  275055       0.00        158816.58          0.245
# 110022    15663942  275056   87848.39         24210.56         -0.195
#
# [110023 rows x 5 columns]

# %%
# Pre-Processed Dataset
df_ppd = df_cat_ppd.join(df_noncat_ppd); df_ppd # Pre-Processed Dataset
# Out:
#        Geography_x Gender_x  Age_x  Tenure_x  NumOfProducts_x  HasCrCard_x  \
# 0           France   Female   23.0         2                2          0.0
# 1           France   Female   46.0         2                1          1.0
# 2           France   Female   34.0         7                2          1.0
# 3           France     Male   36.0         8                1          1.0
# 4          Germany     Male   38.0        10                1          1.0
# ...            ...      ...    ...       ...              ...          ...
# 110018       Spain     Male   29.0         7                1          1.0
# 110019      France   Female   36.0         4                1          1.0
# 110020      France     Male   31.0         2                2          1.0
# 110021      France   Female   32.0         3                1          1.0
# 110022      France   Female   37.0         7                1          1.0
#
# ...

# %%
# Dataset Used : df_ppd

train_df, test_df = train_test_split(df_ppd, test_size=0.25, random_state=1234)
train_df # Training Dataset
test_df # Testing Dataset
# Out:
#        Geography_x Gender_x  Age_x  Tenure_x  NumOfProducts_x  HasCrCard_x  \
# 41698       France   Female   61.0         8                1          1.0
# 101125      France   Female   35.0         9                1          1.0
# 21351       France   Female   57.0         6                3          1.0
# 9424        France   Female   33.0         5                2          1.0
# 32785       France   Female   52.0         3                2          1.0
# ...            ...      ...    ...       ...              ...          ...
# 78878      Germany     Male   33.0         9                1          1.0
# 36126       France     Male   24.0         1                2          1.0
# 21424       France     Male   29.0         9                1          0.0
# 6367        France     Male   30.0         2                2          0.0
# 57781      Germany   Female   24.0         9                1          1.0
#
# ...

# %%
df_ppd.columns
# Out:
# Index(['Geography_x', 'Gender_x', 'Age_x', 'Tenure_x', 'NumOfProducts_x',
#        'HasCrCard_x', 'IsActiveMember_x', 'Surname_x', 'Geography_y',
#        'Gender_y', 'Age_y', 'Tenure_y', 'NumOfProducts_y', 'HasCrCard_y',
#        'IsActiveMember_y', 'Surname_y', 'CustomerId', 'id', 'Balance',
#        'EstimatedSalary', 'CreditScore_y'],
#       dtype='object')

# %%
# Required Libraries
import pandas as pd, numpy as np # For Data Manipulation
import matplotlib.pyplot as plt, seaborn as sns # For Data Visualization
import scipy.cluster.hierarchy as sch # For Hierarchical Clustering
from sklearn.cluster import AgglomerativeClustering as agclus, KMeans as kmclus # For Agglomerative & K-Means Clustering
from sklearn.metrics import silhouette_score as sscore, davies_bouldin_score as dbscore # For Clustering Model Evaluation

# %%
df_bank = df_ppd[['Geography_y',
       'Gender_y', 'Age_y', 'Tenure_y', 'NumOfProducts_y', 'HasCrCard_y','IsActiveMember_y', 'Balance', 'EstimatedSalary', 'CreditScore_y']];
df_bank
# Out:
#         Geography_y  Gender_y  Age_y  Tenure_y  NumOfProducts_y  HasCrCard_y  \
# 0               0.0       0.0    5.0       2.0              1.0          0.0
# 1               0.0       0.0   31.0       2.0              0.0          1.0
# 2               0.0       0.0   17.0       7.0              1.0          1.0
# 3               0.0       1.0   19.0       8.0              0.0          1.0
# 4               1.0       1.0   22.0      10.0              0.0          1.0
# ...             ...       ...    ...       ...              ...          ...
# 110018          2.0       1.0   11.0       7.0              0.0          1.0
# 110019          0.0       0.0   19.0       4.0              0.0          1.0
# 110020          0.0       1.0   13.0       2.0              1.0          1.0
# 110021          0.0       0.0   14.0       3.0              0.0          1.0
# 110022          0.0       0.0   21.0       7.0              0.0          1.0
#
# ...

# %%
# Plot mtcars_subset Data
plt.scatter(x='EstimatedSalary', y='CreditScore_y', data= df_bank, c='CreditScore_y', cmap='Spectral')
plt.xlabel('EstimatedSalary')
plt.ylabel('CreditScore')
plt.title('EstimatedSalary vs CreditScore')
plt.colorbar()
plt.grid()
plt.show()

# %% [markdown]
# 1.Limited Correlation: The data points are dispersed, indicating no apparent linear trend between estimated salary and credit score. This suggests a weak correlation, meaning a high or low salary doesn't necessarily imply a good or bad credit score, and vice versa.
#
# 2.Individuals with good credit scores might enjoy easier access to loans and credit lines, potentially enabling them to pursue career avenues or investments that lead to higher salaries. This complex interplay emphasizes the indirect nature of the relationship.
#
# 3.Even with a wider range, various factors beyond income significantly impact credit scores. Responsible financial management, timely payments, and credit utilization practices play crucial roles. Individuals with high salaries might still have low credit scores due to these factors.

# %% [markdown]
# #K- MEANS CLUSTERING MODEL EVALUATION

# %%
def memory_usage():
    """
    Function to get memory usage.
    """
    process = psutil.Process()
    mem = process.memory_info().rss
    return mem / (1024 * 1024)  # Convert to MB

# %%
#start time
start = time.time()
# Measure memory usage
memory_before = memory_usage()

# %%
wcssd = [] # Within-Cluster-Sum-Squared-Distance
nr_clus = range(1,11) # Number of Clusters
for k in nr_clus:
    kmeans = kmclus(n_clusters=k, init='random', random_state=111)
    kmeans.fit(df_bank)
    wcssd.append(kmeans.inertia_)
plt.plot(nr_clus, wcssd, marker='x')
plt.xlabel('Values of K')
plt.ylabel('Within Cluster Sum Squared Distance')
plt.title('Elbow Curve for Optimal K')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %% [markdown]
# •	The line graph exhibits a decreasing trend, followed by a notable leveling off around a k value of 4.
#
# •	The x-axis ticks range from 2 to 10, and the y-axis values seem to span from 0 to 16, though the precise tick marks are somewhat challenging to discern.
#
# •	The objective is to identify the k value at which the within-cluster sum of squared distances starts to exhibit diminishing returns. In our case, the line levels off around k=4.
#
# •	This suggests that adding more clusters beyond k=4 doesn't significantly reduce the within-cluster sum of squared distances, indicating a potential optimal number of clusters.
#
# •	Selecting the optimal number of clusters is a critical decision in cluster analysis.
#
# •	The Elbow Curve analysis suggests that k=4 may be an appropriate choice for forming clusters that minimize within-cluster distances.

# %%
km_2cluster = kmclus(n_clusters=2, init='random', random_state=222)
km_2cluster_model = km_2cluster.fit_predict(df_bank); km_2cluster_model
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# array([0, 0, 0, ..., 0, 0, 1], dtype=int32)

# %%
km_3cluster = kmclus(n_clusters=3, init='random', random_state=333)
km_3cluster_model = km_3cluster.fit_predict(df_bank); km_3cluster_model
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# array([1, 2, 1, ..., 2, 1, 2], dtype=int32)

# %%
km_4cluster = kmclus(n_clusters=4, init='random', random_state=444)
km_4cluster_model = km_4cluster.fit_predict(df_bank); km_4cluster_model
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# array([2, 0, 2, ..., 0, 2, 1], dtype=int32)

# %%
km_5cluster = kmclus(n_clusters=5, init='random', random_state=555)
km_5cluster_model = km_5cluster.fit_predict(df_bank); km_5cluster_model
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# array([1, 0, 1, ..., 3, 1, 2], dtype=int32)

# %%
sscore_km_2cluster = sscore(df_bank, km_2cluster_model); print(sscore_km_2cluster)
dbscore_km_2cluster = dbscore(df_bank, km_2cluster_model); dbscore_km_2cluster
# Out:
# 0.5491845218598962
# 0.7634571922671449

# %% [markdown]
# Silhouette Score (SS):
#
# The SS score of 0.5492 indicates a moderate level of separation and cohesion
# among the clusters.
# A score closer to 1 suggests dense and well-separated clusters, while a score closer to -1 indicates overlapping clusters.
#
# Davies-Bouldin Score (DB):
#
# The DB score of 0.7635 suggests that the clusters are relatively well-separated, but there may be some overlap or ambiguity in cluster boundaries.
# Lower DB scores indicate better clustering, with values closer to 0 representing clear and distinct clusters.

# %%
 sscore_km_3cluster = sscore(df_bank, km_3cluster_model); print(sscore_km_3cluster)
dbscore_km_3cluster = dbscore(df_bank, km_3cluster_model); dbscore_km_3cluster
# Out:
# 0.536173473290008
# 0.569675383102555

# %% [markdown]
# Silhouette Score (SS):
#
# The SS score of 0.5362 indicates a moderate level of separation and cohesion among the clusters.
# A score closer to 1 suggests dense and well-separated clusters, while a score closer to -1 indicates overlapping clusters.
# While the SS score is not exceptionally high, it still suggests a reasonable clustering arrangement with some degree of distinctiveness among clusters.
#
# Davies-Bouldin Score (DB):
#
# The DB score of 0.5697 suggests that the clusters are relatively well-separated, but there may be some overlap or ambiguity in cluster boundaries.
# Lower DB scores indicate better clustering, with values closer to 0 representing clear and distinct clusters.
# The obtained DB score indicates a moderate level of clustering quality, with room for potential improvement in cluster separation.

# %%
sscore_km_4cluster = sscore(df_bank, km_4cluster_model); print(sscore_km_4cluster)
dbscore_km_4cluster = dbscore(df_bank, km_4cluster_model); dbscore_km_4cluster
# Out:
# 0.5512503686405491
# 0.638378533421054

# %% [markdown]
# Silhouette Score (SS):
#
# The SS score of 0.5512 indicates a moderate level of separation and cohesion among the clusters.
# A score closer to 1 suggests dense and well-separated clusters, while a score closer to -1 indicates overlapping clusters.
# While the SS score is not exceptionally high, it still suggests a reasonable clustering arrangement with some degree of distinctiveness among clusters.
#
# Davies-Bouldin Score (DB):
#
# The DB score of 0.6384 suggests that the clusters are relatively well-separated, but there may be some overlap or ambiguity in cluster boundaries.
# Lower DB scores indicate better clustering, with values closer to 0 representing clear and distinct clusters.
# The obtained DB score indicates a moderate level of clustering quality, with room for potential improvement in cluster separation.

# %%
sscore_km_5cluster = sscore(df_bank, km_5cluster_model); print(sscore_km_5cluster)
dbscore_km_5cluster = dbscore(df_bank, km_5cluster_model); dbscore_km_5cluster
# Out:
# 0.5182375917851972
# 0.6393821508031465

# %% [markdown]
# Silhouette Score (SS):
#
# The SS score of 0.5182 suggests a moderate level of separation and cohesion among the clusters.
# A score closer to 1 indicates dense, well-separated clusters, while a score closer to -1 suggests overlapping clusters.
# While the SS score is not exceptionally high, it still indicates a reasonable clustering arrangement with some degree of distinctiveness among clusters.
#
# Davies-Bouldin Score (DB):
#
# The DB score of 0.6394 indicates that the clusters are relatively well-separated, but there may be some overlap or ambiguity in cluster boundaries.
# Lower DB scores represent better clustering, with values closer to 0 indicating clear and distinct clusters.
# The obtained DB score suggests a moderate level of clustering quality, with potential room for improvement in cluster separation.

# %%
df_bank_kmcluster = df_bank.copy()
df_bank_kmcluster['cluster_number'] = km_4cluster_model
df_bank_kmcluster.sort_values('cluster_number', inplace=True)

# %%
df_bank_kmcluster.columns
# Out:
# Index(['Geography_y', 'Gender_y', 'Age_y', 'Tenure_y', 'NumOfProducts_y',
#        'HasCrCard_y', 'IsActiveMember_y', 'Balance', 'EstimatedSalary',
#        'CreditScore_y', 'cluster_number'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D


# Create a new figure and specify 3D projection
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

# Define colors and labels for clusters
cluster_labels = df_bank_kmcluster['cluster_number'].unique()
colors = ['b', 'g', 'r', 'c', 'm', 'y', 'k']

# Plot each cluster
for i, cluster_label in enumerate(cluster_labels):
    cluster_data = df_bank_kmcluster[df_bank_kmcluster['cluster_number'] == cluster_label]
    ax.scatter(cluster_data['EstimatedSalary'], cluster_data['CreditScore_y'], cluster_data['cluster_number'], c=colors[i], label=f'Cluster {cluster_label}')

# Set labels and title
ax.set_xlabel('EstimatedSalary')
ax.set_ylabel('CreditScore')
ax.set_zlabel('Cluster Number')
ax.set_title('CustomerId vs CreditScore Scatter Plot : K-Means Clusters')

# Add legend
ax.legend()

# Show grid
ax.grid(True)

# Show the plot
plt.show()

# %% [markdown]
# K-means clustering is a machine learning technique that is used to group data points into a specific number of clusters. In this case, the data points are customers, and the two features are customer ID and credit score. The k-means algorithm has identified four clusters of customers based on their credit scores.
#
# The credit score is on the y-axis, and it ranges from 0 to 3. The customer ID is on the x-axis, but it appears to be anonymized or hashed, so it is not possible to identify individual customers.
#
# The clusters are somewhat spread out, but there does appear to be some clustering around certain credit score values. For example, Cluster 1 seems to contain customers with credit scores between 1.5 and 2.5. Cluster 3 seems to contain customers with credit scores between 2.0 and 3.0.

# %%
# end time
end = time.time()
# Memory afterward
memory_after = memory_usage()

# total time taken
print(f"Runtime of the program is {end - start}")
print("Memory usage difference:", memory_after - memory_before, "MB")
# Out:
# Runtime of the program is 239.1533546447754
# Memory usage difference: 12.328125 MB

# %%
df_cluster_0 = df_bank_kmcluster[df_bank_kmcluster['cluster_number'] == 0]
df_cluster_1 = df_bank_kmcluster[df_bank_kmcluster['cluster_number'] == 1]
df_cluster_2 = df_bank_kmcluster[df_bank_kmcluster['cluster_number'] == 2]
df_cluster_3 = df_bank_kmcluster[df_bank_kmcluster['cluster_number'] == 3]

# %%
df_cluster_0.describe()
# Out:
#         Geography_y      Gender_y         Age_y      Tenure_y  \
# count  27653.000000  27653.000000  27653.000000  27653.000000
# mean       0.536253      0.578020     21.057245      5.014754
# std        0.884329      0.493884      9.762544      2.773920
# min        0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000     14.000000      3.000000
# 50%        0.000000      1.000000     19.000000      5.000000
# 75%        2.000000      1.000000     25.000000      7.000000
# max        2.000000      1.000000     73.000000     10.000000
#
#        NumOfProducts_y   HasCrCard_y  IsActiveMember_y       Balance  \
# count     27653.000000  27653.000000      27653.000000  27653.000000
# mean          0.744585      0.762268          0.506130    437.056140
# std           0.482179      0.425702          0.499971   4787.369013
# min           0.000000      0.000000          0.000000      0.000000
# ...

# %%
# ANOVA for  valence
mean_test_anova_scipy_Balance= sps.f_oneway(df_cluster_0.Balance, df_cluster_1.Balance,df_cluster_2.Balance,df_cluster_3.Balance) # ANOVA
mean_test_anova_scipy_Balance
# Out:
# F_onewayResult(statistic=489499.2594413773, pvalue=0.0)

# %% [markdown]
# Since the p-value is less than the significance level (usually 0.05), we reject the null hypothesis, suggesting that there are statistically significant differences in the mean 'Balance' across at least one pair of clusters.
#
# The high F-statistic further supports the rejection of the null hypothesis, indicating substantial variation in 'Balance' among the clusters.
#
# Therefore, we can conclude that there are significant differences in the mean 'Balance' across the clusters, implying that the 'Balance' variable contributes significantly to distinguishing between the clusters.

# %%
# ANOVA for  valence
mean_test_anova_scipy_EstimatedSalary= sps.f_oneway(df_cluster_0.EstimatedSalary, df_cluster_1.EstimatedSalary,df_cluster_2.EstimatedSalary,df_cluster_3.EstimatedSalary) # ANOVA
mean_test_anova_scipy_EstimatedSalary
# Out:
# F_onewayResult(statistic=97042.28085304164, pvalue=0.0)

# %% [markdown]
# With a p-value significantly lower than the typical significance level of 0.05, we reject the null hypothesis, indicating that there are statistically significant differences in the mean 'EstimatedSalary' across at least one pair of clusters.
#
# The high F-statistic further supports the rejection of the null hypothesis, suggesting substantial variation in 'EstimatedSalary' among the clusters.
#
# Consequently, we can conclude that the 'EstimatedSalary' variable significantly influences the clustering of data, underscoring its importance in delineating customer segments based on their salary estimations.

# %%
# ANOVA for  valence
mean_test_anova_scipy_CreditScore_y= sps.f_oneway(df_cluster_0.CreditScore_y, df_cluster_1.CreditScore_y,df_cluster_2.CreditScore_y,df_cluster_3.CreditScore_y) # ANOVA
mean_test_anova_scipy_CreditScore_y
# Out:
# F_onewayResult(statistic=2.049253433681099, pvalue=0.10464511169584538)

# %% [markdown]
# With a p-value greater than the conventional significance level of 0.05, we fail to reject the null hypothesis.
#
# The obtained p-value suggests that there is no statistically significant difference in the mean 'CreditScore_y' among the clusters.
#
# Therefore, we infer that the 'CreditScore_y' variable may not significantly contribute to the clustering of data, as there is insufficient evidence to support its influence on cluster formation.

# %%
# Pairwise Comparision Using Scipy (Tukey HSD)
mean_pairwise_compare_scipy_Balance = sps.tukey_hsd(df_cluster_0.Balance, df_cluster_1.Balance,df_cluster_2.Balance,df_cluster_3.Balance)
print(mean_pairwise_compare_scipy_Balance)
# Out:
# Tukey's HSD Pairwise Group Comparisons (95.0% Confidence Interval)
# Comparison  Statistic  p-value  Lower CI  Upper CI
#  (0 - 1) -121479.040     0.000-121861.611-121096.469
#  (0 - 2)     79.856     0.935  -268.056   427.768
#  (0 - 3) -121796.137     0.000-122159.744-121432.529
#  (1 - 0) 121479.040     0.000121096.469121861.611
#  (1 - 2) 121558.896     0.000121189.791121928.001
#  (1 - 3)   -317.097     0.146  -701.032    66.839
#  (2 - 0)    -79.856     0.935  -427.768   268.056
#  (2 - 1) -121558.896     0.000-121928.001-121189.791
#  (2 - 3) -121875.992     0.000-122225.404-121526.581
#  (3 - 0) 121796.137     0.000121432.529122159.744
#  (3 - 1)    317.097     0.146   -66.839   701.032
#  (3 - 2) 121875.992     0.000121526.581122225.404

# %%
# Pairwise Comparision Using Scipy (Tukey HSD)
mean_pairwise_compare_scipy_EstimatedSalary = sps.tukey_hsd(df_cluster_0.EstimatedSalary, df_cluster_1.EstimatedSalary,df_cluster_2.EstimatedSalary,df_cluster_3.EstimatedSalary)
print(mean_pairwise_compare_scipy_EstimatedSalary)
# Out:
# Tukey's HSD Pairwise Group Comparisons (95.0% Confidence Interval)
# Comparison  Statistic  p-value  Lower CI  Upper CI
#  (0 - 1)   -461.240     0.207 -1068.920   146.440
#  (0 - 2) -86017.941     0.000-86570.568-85465.313
#  (0 - 3) -86441.536     0.000-87019.095-85863.977
#  (1 - 0)    461.240     0.207  -146.440  1068.920
#  (1 - 2) -85556.701     0.000-86142.991-84970.410
#  (1 - 3) -85980.296     0.000-86590.143-85370.449
#  (2 - 0)  86017.941     0.000 85465.313 86570.568
#  (2 - 1)  85556.701     0.000 84970.410 86142.991
#  (2 - 3)   -423.595     0.203  -978.604   131.414
#  (3 - 0)  86441.536     0.000 85863.977 87019.095
#  (3 - 1)  85980.296     0.000 85370.449 86590.143
#  (3 - 2)    423.595     0.203  -131.414   978.604

# %%
from scipy.stats import chi2_contingency

# Extracting categorical variables
cat_variables = ['Geography_y', 'Gender_y','Age_y','Tenure_y','NumOfProducts_y','HasCrCard_y','IsActiveMember_y','IsActiveMember_y']

# Perform Chi-square test for each categorical variable
chi2_results_cat = {}
for column in cat_variables:
    contingency_table = pd.crosstab(df_bank_kmcluster[column], km_4cluster_model)
    chi2, p_value, _, _ = chi2_contingency(contingency_table)
    chi2_results_cat[column] = {'Chi-square': chi2, 'P-value': p_value}

# Print Chi-square test results for categorical variables
for column, result in chi2_results_cat.items():
    print(f"for: {column}")
    print(f"Chi-square: {result['Chi-square']}")
    print(f"P-value: {result['P-value']}")
    print("____")
# Out:
# for: Geography_y
# Chi-square: 5.073258875168252
# P-value: 0.5344520899596663
# ____
# for: Gender_y
# Chi-square: 3.0030417451762297
# P-value: 0.39115643670799355
# ____
# for: Age_y
# Chi-square: 199.8490503425403
# P-value: 0.8188761358110948
# ____
# for: Tenure_y
# Chi-square: 56.01861886359349
# P-value: 0.002716920750940767
# ____
# for: NumOfProducts_y
# Chi-square: 11.13549361100677
# P-value: 0.2665357997402213
# ____
# for: HasCrCard_y
# Chi-square: 2.0747565245306623
# P-value: 0.5570365474207075
# ____
# for: IsActiveMember_y
# Chi-square: 9.209110610289695
# P-value: 0.026636046227971402
# ____

# %% [markdown]
# •	Despite having a relatively high Chi-square value, the p-value suggests that age is not significantly associated with the target variable. This indicates that customers' ages may not have a substantial impact on the outcome being studied.
#
# •	tenure exhibits a significant association with the target variable, as evidenced by the low p-value. This implies that the length of time a customer has been with the bank could be a critical factor influencing the outcome.
#
# •	The analysis suggests that the number of products held by customers does not have a significant association with the target variable. Thus, the quantity of products utilized by customers may not strongly influence the outcome.
#
# •	holding a credit card does not appear to be significantly associated with the target variable. This implies that possessing a credit card may not be a determining factor in the outcome under consideration.
#
# •	Active membership status shows a significant association with the target variable, as indicated by the low p-value. This suggests that customers' engagement with bank services as active members may impact the outcome being analyzed.

# %%
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler

# %%
categorical = df.select_dtypes("object").columns.values
numerical = np.setdiff1d(df.columns, categorical)
continuous = df.select_dtypes(float).columns.values
discrete = np.setdiff1d(numerical, continuous)

print(categorical, numerical, continuous, sep = "\n")
# Out:
# ['Surname' 'Geography' 'Gender']
# ['Age' 'Balance' 'CreditScore' 'CustomerId' 'EstimatedSalary' 'HasCrCard'
#  'IsActiveMember' 'NumOfProducts' 'Tenure' 'id']
# ['Age' 'Balance' 'HasCrCard' 'IsActiveMember' 'EstimatedSalary']

# %%
sns.pairplot(df.loc[:, continuous])
plt.show()

# %%
from sklearn.mixture import GaussianMixture
from sklearn.preprocessing import StandardScaler

# Assuming you have a DataFrame called 'df_ppd' with preprocessed data
# Standardize the data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(df_bank)  # Corrected line

# Initialize and fit the Gaussian Mixture Model
n_components = 2 # You can adjust the number of components/clusters
gmm = GaussianMixture(n_components=n_components, random_state=142)
gmm.fit(X_scaled)

# Get cluster labels
cluster_labels = gmm.predict(X_scaled)
df_bank.reset_index(level=0, inplace=True, names='CustomerId_y')
# Add cluster labels to the DataFrame
df_bank['Cluster'] = cluster_labels

# Display the DataFrame with cluster labels
df_bank
# Out:
# <ipython-input-109-eadc95e5729d>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bank['Cluster'] = cluster_labels
#         CustomerId_y  Geography_y  Gender_y  Age_y  Tenure_y  NumOfProducts_y  \
# 0                  0          0.0       0.0    5.0       2.0              1.0
# 1                  1          0.0       0.0   31.0       2.0              0.0
# 2                  2          0.0       0.0   17.0       7.0              1.0
# 3                  3          0.0       1.0   19.0       8.0              0.0
# 4                  4          1.0       1.0   22.0      10.0              0.0
# ...              ...          ...       ...    ...       ...              ...
# ...

# %%
from sklearn.metrics import silhouette_score, davies_bouldin_score

# Calculate silhouette score
silhouette_score_value = silhouette_score(X_scaled, cluster_labels)

# Calculate Davies-Bouldin score
davies_bouldin_score_value = davies_bouldin_score(X_scaled, cluster_labels)

print("Silhouette Score:", silhouette_score_value)
print("Davies-Bouldin Score:", davies_bouldin_score_value)
# Out:
# Silhouette Score: 0.1076994105124071
# Davies-Bouldin Score: 2.916945875033011

# %% [markdown]
# Silhouette Score Interpretation:
#
# A score close to +1 indicates that the object is well-clustered, while a score close to -1 indicates misclassification.
# In this case, the silhouette score of 0.1077 suggests that the clusters are not well-separated, as the score is closer to 0 than to +1. This indicates that many data points may be close to the decision boundary between clusters.
#
# Davies-Bouldin Score Interpretation:
#
# A score closer to 0 indicates better separation, while higher scores suggest more overlap between clusters.
# With a Davies-Bouldin score of 2.9169, there is moderate overlap or ambiguity in cluster boundaries, indicating suboptimal clustering.
#
# Overall Analysis:
#
# The obtained scores suggest that the clustering algorithm may not be highly effective in segregating the data into well-defined clusters.
# The low silhouette score and relatively high Davies-Bouldin score indicate that the clusters are not well-separated and may exhibit significant overlap or ambiguity.

# %%
#start time
start1 = time.time()
# Measure memory usage
memory_before1 = memory_usage()

# %%
model = Birch(branching_factor = 50, n_clusters = 2, threshold = 1.5)
# Fit the model to the data
pred=model.fit(df_bank)
# Get cluster labels
cluster_labels2 = pred.labels_
# Get cluster labels
cluster_labels2

# %% [markdown]
# PROBLEM AND SEGMENTATIONS
#
# The problem statement articulates the specific challenge or issue that needs to be addressed through analysis, research, or intervention.
#
# Segmentation involves dividing a heterogeneous market or customer base into smaller, more homogeneous groups based on certain criteria. In the context of customer churn prediction, segmentation refers to the process of categorizing customers into distinct groups or segments, each exhibiting similar characteristics or behaviors.

# %% [markdown]
# #MANAGERIAL IMPLICATIONS
#
# •	Individuals in this cluster may have limited financial resources. Tailor marketing strategies to offer budget-friendly products, financial education resources, or assistance programs.
#
#
#
# *  Understanding whether the formed clusters are homogeneous or heterogeneous is crucial. Homogeneous clusters suggest similar customer profiles, allowing for targeted and streamlined strategies. In contrast, heterogeneous clusters may indicate diverse customer segments, necessitating a more adaptable approach.
#
# *  The choice of a clustering algorithm has direct implications for the effectiveness of subsequent strategies. Decision-makers should invest time in understanding the nuances of various algorithms and select the one that aligns best with the dataset characteristics.
#
# The optimal number of clusters is pivotal for actionable insights. A clear understanding of k allows for precise segmentation, enabling the bank to tailor services, marketing, and retention strategies to the specific needs of each cluster.
#
# The interpretability of clusters is paramount. Decision-makers should ensure that the identified clusters make sense in the context of banking operations. Aligning clusters with domain knowledge and business objectives enhances the practicality and utility of the analysis.
#
#  Experimenting with clustering algorithm parameters can significantly impact model performance. Decision-makers should actively engage in parameter fine-tuning to optimize the clustering model for better accuracy and relevance.
#
#
#
# •	Focus on marketing campaigns that appeal to young professionals or individuals with moderate credit history. Offer products and services suitable for early career stages.
#
# •	Target customers with established careers and strong financial standing. Introduce premium services, exclusive benefits, or high-value products to cater to their financial capacity.
#
# •	Develop strategies to engage individuals with high earning potential but limited credit history. Offer tailored financial solutions, credit-building programs, or services catering to their unique needs.
#
# •	Design products and services that cater to the diverse financial needs of each cluster. Customize features, interest rates, and benefits to align with the characteristics of customers in different segments.
